# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import OMY_STATS as om
# Out:
# Total Sum: 230
# Total Count: 16
# Maximum Value: 24
# Minimum Value: 3
# Range: 21
# Mean: 14.375
# Median: 17.0
# No Mode
# Standard Deviation: 9.433152972362953
# Standard Deviation: 9.433152972362953
# Skewness: -0.19631208077302495
# Kurtosis: -1.9191209079855711
# Q1: 3.0
# Q3: <bound method cal_stats.iqr of <OMY_STATS.cal_stats object at 0x0000024C3478BE00>>
# IQR: 21.0
# Lower Whisker: -28.5
# Upper Whisker: 55.5
# Total Outliers Count: 0
# Variance: 94.91666666666667
# Standard Deviation: 9.742518497116988
# 1 Standard Deviation Range: (4.632482 to 24.117518) --> 62.50% of data
# 2 Standard Deviation Range: (-5.110037 to 33.860037) --> 100.00% of data
# 3 Standard Deviation Range: (-14.852555 to 43.602555) --> 100.00% of data
# 95% Confidence Interval: 9.752755,18.997245
# 97% Confidence Interval: 9.257515,19.492485
# 99% Confidence Interval: 8.300049,20.449951
# Likely Does Not Follow Normal Distribution

# %%
df=pd.read_csv('USA_Housing.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
# dtypes: float64(6)
# memory usage: 234.5 KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928700  9.975771e+05
# 50%                        4.050000     36199.406690  1.232669e+06
# 75%                        4.490000     42861.290770  1.471210e+06
# max                        6.500000     69621.713380  2.469066e+06

# %%
for col_name in df.columns:
    print(col_name)
    st_obj=om.cal_stats(df[col_name])
    st_obj.everything()
# Out:
# Avg. Area Income
# Total Sum: 342915544.91985
# Total Count: 5000
# Maximum Value: 107701.7484
# Minimum Value: 17796.63119
# Range: 89905.11721
# Mean: 68583.10898397
# Median: 68804.28640499999
# No Mode
# Standard Deviation: 10656.92536147202
# Standard Deviation: 10656.92536147202
# Skewness: -0.03369974605287991
# Kurtosis: 0.043110890763585985
# Q1: 61480.56239
# Q3: <bound method cal_stats.iqr of <OMY_STATS.cal_stats object at 0x0000024C34A6AA80>>
# IQR: 14302.77627499999
# Lower Whisker: 40026.39797750002
# Upper Whisker: 97237.50307749998
# Total Outliers Count: 32
# Variance: 113592776.71532859
# Standard Deviation: 10657.991213888694
# 1 Standard Deviation Range: (57925.117770 to 79241.100198) --> 68.72% of data
# 2 Standard Deviation Range: (47267.126556 to 89899.091412) --> 95.40% of data
# 3 Standard Deviation Range: (36609.135342 to 100557.082626) --> 99.74% of data
# 95% Confidence Interval: 68287.714084,68878.503884
# 97% Confidence Interval: 68256.064630,68910.153338
# 99% Confidence Interval: 68194.875687,68971.342281
# Likely Follows Normal Distribution
# Detected Continous Data
# C:\Users\Om Singh\Master Code Folder\OMY_STATS.py:106: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(self.data)
# Avg. Area House Age
# Total Sum: 29886.110176435
# Total Count: 5000
# Maximum Value: 9.519088066
# Minimum Value: 2.644304186
# Range: 6.874783880000001
# Mean: 5.977222035287
# Median: 5.970428947
# No Mode
# Standard Deviation: 0.9913570292566625
# Standard Deviation: 0.9913570292566625
# Skewness: -0.007209544621788692
# Kurtosis: -0.08571970912493532
# Q1: 5.32228301575
# Q3: <bound method cal_stats.iqr of <OMY_STATS.cal_stats object at 0x0000024C34C18F80>>
# IQR: 1.3285254635000001
# Lower Whisker: 3.3294948205
# Upper Whisker: 8.6435966745
# Total Outliers Count: 25
# Variance: 0.9829853565279006
# Standard Deviation: 0.9914561798324224
# 1 Standard Deviation Range: (4.985766 to 6.968678) --> 68.06% of data
# 2 Standard Deviation Range: (3.994310 to 7.960134) --> 95.46% of data
# 3 Standard Deviation Range: (3.002853 to 8.951591) --> 99.80% of data
# 95% Confidence Interval: 5.949743,6.004701
# 97% Confidence Interval: 5.946799,6.007645
# 99% Confidence Interval: 5.941107,6.013337
# Likely Follows Normal Distribution
# Detected Continous Data
# C:\Users\Om Singh\Master Code Folder\OMY_STATS.py:106: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(self.data)
# Avg. Area Number of Rooms
# Total Sum: 34938.959254546004
# Total Count: 5000
# Maximum Value: 10.75958834
# Minimum Value: 3.236194023
# Range: 7.523394317000001
# Mean: 6.9877918509092005
# Median: 7.0029019869999996
# No Mode
# Standard Deviation: 1.005732642922613
# Standard Deviation: 1.005732642922613
# Skewness: -0.04097131586251815
# Kurtosis: -0.07694686692088082
# Q1: 6.2992501
# Q3: <bound method cal_stats.iqr of <OMY_STATS.cal_stats object at 0x0000024C35606240>>
# IQR: 1.3666213477499998
# Lower Whisker: 4.249318078375
# Upper Whisker: 9.715803469375
# Total Outliers Count: 24
# Variance: 1.0117004891379318
# Standard Deviation: 1.0058332312754097
# 1 Standard Deviation Range: (5.981959 to 7.993625) --> 67.56% of data
# 2 Standard Deviation Range: (4.976125 to 8.999458) --> 95.46% of data
# 3 Standard Deviation Range: (3.970292 to 10.005292) --> 99.82% of data
# 95% Confidence Interval: 6.959914,7.015669
# 97% Confidence Interval: 6.956927,7.018656
# 99% Confidence Interval: 6.951153,7.024431
# Likely Follows Normal Distribution
# Detected Continous Data
# C:\Users\Om Singh\Master Code Folder\OMY_STATS.py:106: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(self.data)
# Avg. Area Number of Bedrooms
# Total Sum: 19906.65
# Total Count: 5000
# Maximum Value: 6.5
# Minimum Value: 2.0
# Range: 4.5
# Mean: 3.9813300000000003
# Median: 4.05
# Mode: 4.38
# Standard Deviation: 1.2340138455868308
# Standard Deviation: 1.2340138455868308
# Skewness: 0.37601468307644537
# Kurtosis: -0.7029830384031248
# Q1: 3.14
# Q3: <bound method cal_stats.iqr of <OMY_STATS.cal_stats object at 0x0000024C354E39B0>>
# IQR: 1.35
# Lower Whisker: 1.1149999999999998
# Upper Whisker: 6.515000000000001
# Total Outliers Count: 0
# Variance: 1.5230947900580103
# Standard Deviation: 1.2341372654846827
# 1 Standard Deviation Range: (2.747193 to 5.215467) --> 64.54% of data
# 2 Standard Deviation Range: (1.513055 to 6.449605) --> 98.56% of data
# 3 Standard Deviation Range: (0.278918 to 7.683742) --> 100.00% of data
# 95% Confidence Interval: 3.947125,4.015535
# 97% Confidence Interval: 3.943460,4.019200
# 99% Confidence Interval: 3.936375,4.026285
# Likely Does Not Follow Normal Distribution
# Detected Continous Data
# C:\Users\Om Singh\Master Code Folder\OMY_STATS.py:106: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(self.data)
# Area Population
# Total Sum: 180817580.1927013
# Total Count: 5000
# Maximum Value: 69621.71338
# Minimum Value: 172.6106863
# Range: 69449.1026937
# Mean: 36163.516038540256
# Median: 36199.40669
# No Mode
# Standard Deviation: 9924.657498901459
# Standard Deviation: 9924.657498901459
# Skewness: 0.05061929579320106
# Kurtosis: -0.00912265839642279
# Q1: 29403.9287
# Q3: <bound method cal_stats.iqr of <OMY_STATS.cal_stats object at 0x0000024C3551E810>>
# IQR: 13457.36207
# Lower Whisker: 9217.885595000003
# Upper Whisker: 63047.333875
# Total Outliers Count: 30
# Variance: 98518530.17653626
# Standard Deviation: 9925.650113546028
# 1 Standard Deviation Range: (26237.865925 to 46089.166152) --> 68.28% of data
# 2 Standard Deviation Range: (16312.215811 to 56014.816266) --> 95.24% of data
# 3 Standard Deviation Range: (6386.565698 to 65940.466379) --> 99.68% of data
# 95% Confidence Interval: 35888.418568,36438.613509
# 97% Confidence Interval: 35858.943839,36468.088238
# 99% Confidence Interval: 35801.959363,36525.072714
# Likely Follows Normal Distribution
# Detected Continous Data
# C:\Users\Om Singh\Master Code Folder\OMY_STATS.py:106: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(self.data)
# Price
# Total Sum: 6160363270.7265
# Total Count: 5000
# Maximum Value: 2469065.594
# Minimum Value: 15938.65792
# Range: 2453126.93608
# Mean: 1232072.6541453
# Median: 1232669.378
# No Mode
# Standard Deviation: 353082.3130552728
# Standard Deviation: 353082.3130552728
# Skewness: -0.0027164343102613737
# Kurtosis: -0.05724042333505519
# Q1: 997577.135075
# Q3: <bound method cal_stats.iqr of <OMY_STATS.cal_stats object at 0x0000024C35A6F7A0>>
# IQR: 473633.069425
# Lower Whisker: 287127.53093749995
# Upper Whisker: 2181659.8086375
# Total Outliers Count: 35
# Variance: 124692058204.1025
# Standard Deviation: 353117.6265836959
# 1 Standard Deviation Range: (878955.027562 to 1585190.280729) --> 68.14% of data
# 2 Standard Deviation Range: (525837.400978 to 1938307.907313) --> 95.66% of data
# 3 Standard Deviation Range: (172719.774394 to 2291425.533896) --> 99.74% of data
# 95% Confidence Interval: 1222285.711748,1241859.596542
# 97% Confidence Interval: 1221237.110777,1242908.197513
# 99% Confidence Interval: 1219209.815567,1244935.492724
# Likely Follows Normal Distribution
# Detected Continous Data
# C:\Users\Om Singh\Master Code Folder\OMY_STATS.py:106: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(self.data)

# %%
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# dtype: int64

# %% [markdown]
# ##

# %% [markdown]
# # #ML FLOW
# 1. Defining Problem Statement
# 2. Collecting Data
# 3. Reading Data In Python
# 4. Data Pre Processing
# 5. Defining Input & Output
# 6. Train Test Split
# 7. Training ML Model
# 8. Evaluating Model
# 9. Save Model
# 10. Deploy Model

# %%
X=df.drop('Price',axis=1)
y=df['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2,random_state=555)

# %%
df.shape
# Out:
# (5000, 6)

# %%
print('X train Shape:',X_train.shape)
print('X test Shape:',X_test.shape)
print('y train Shape:',y_train.shape)
print('y test Shape:',y_test.shape)
# Out:
# X train Shape: (4000, 5)
# X test Shape: (1000, 5)
# y train Shape: (4000,)
# y test Shape: (1000,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
col_index=0
for i in lr.coef_:
    print(df.columns[col_index])
    print('slope:', round(i,2))
    col_index+=1
    print('*'*30)
print('Y-intercept:',lr.intercept_)
# Out:
# Avg. Area Income
# slope: 21.59
# ******************************
# Avg. Area House Age
# slope: 164499.23
# ******************************
# Avg. Area Number of Rooms
# slope: 119970.77
# ******************************
# Avg. Area Number of Bedrooms
# slope: 2059.82
# ******************************
# Area Population
# slope: 15.29
# ******************************
# Y-intercept: -2630570.442158453

# %%
sse=sum(y_test-y_pred)**2
print('Sum Of Squared Error:',sse)

mse= sse/len(X_test)
print('Mean Sqaure Error:',mse)

rmse= np.sqrt(mse)
print('Root Mean Square Error:',rmse)
# Out:
# Sum Of Squared Error: 25431524287295.32
# Mean Sqaure Error: 25431524287.29532
# Root Mean Square Error: 159472.64432276564

# %%
sns.distplot(y_test-y_pred)
# Out:
# C:\Users\Om Singh\AppData\Local\Temp\ipykernel_23580\520176394.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-y_pred)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
for i in df.iloc[2452].values:
    print(i)
# Out:
# 77521.05738
# 6.444728491
# 7.077553855
# 5.43
# 32624.6465
# 1501622.125

# %%
income=float(input('What is Your Avg. Area Income'))
age=float(input('What is your House Age'))
rooms=float(input('What is your Number of Rooms'))
bedroom=float(input('What is your Number of Bedrooms'))
pop=float(input('What is your Area Population'))
user_input=np.array([income,age,rooms,bedroom,pop])
# Out:
# What is Your Avg. Area Income 77521.05738
# What is your House Age 6.444728491
# What is your Number of Rooms 7.077553855
# What is your Number of Bedrooms 5.43
# What is your Area Population 32624.6465

# %%
house_price_pred=lr.predict(user_input.reshape(1, -1))
print(f'Your House can be sold between %{round(house_price_pred[0])-50000} to ${round(house_price_pred[0])+50000}')
# Out:
# Your House can be sold between %1412615 to $1512615
# C:\Users\Om Singh\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\om singh\anaconda3\lib\site-packages (1.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib
joblib.dump(lr, 'usa house price pred model 100k rmse 25-08-25.pkl')
# Out:
# ['usa house price pred model 100k rmse 25-08-25.pkl']
